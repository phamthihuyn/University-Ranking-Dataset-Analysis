# %% [markdown]
# **Import pandas and read data**

# %%
import pandas as pd

data = pd.read_csv('World+University+Rankings+2023.csv')
df = pd.DataFrame(data)
df
# Out:
#      University Rank                     Name of University        Location  \
# 0                  1                   University of Oxford  United Kingdom
# 1                  2                     Harvard University   United States
# 2                  3                University of Cambridge  United Kingdom
# 3                  3                    Stanford University   United States
# 4                  5  Massachusetts Institute of Technology   United States
# ...              ...                                    ...             ...
# 2336               -     University of the West of Scotland             NaN
# 2337               -                  University of Windsor             NaN
# 2338               -            University of Wolverhampton             NaN
# 2339               -                University of Wuppertal             NaN
# 2340               -    Xi’an Jiaotong-Liverpool University             NaN
#
# ...

# %% [markdown]
# **Counting Universities**

# %%
df_uni = df.groupby('Name of University')
print('The number of universities:', len(df_uni))
# Out:
# The number of universities: 2233

# %% [markdown]
# **Counting Countries**

# %%
grouped_countries = df.groupby('Location')
print('The number of countries:', len(grouped_countries))
# Out:
# The number of countries: 116

# %% [markdown]
# **Tuple get the number of rows and column**

# %%
df.shape
# Out:
# (2341, 13)

# %% [markdown]
# **Remove Na value from data. Checking whether unique Universities are equal to number of rows of data.
# If not return the specified error messsage**

# %%
df.dropna(inplace=True)
assert df['Name of University'].nunique() == df.shape[0], f"Data granularity check failed! Expected: {len(df_uni)}, but recieve {df.shape[0]}"

# %% [markdown]
# **Country Distribution in Top 100:**

# %% [markdown]
# 1. Converting Series University Rank Type to List

# %%
df['University Rank'] = df['University Rank'].tolist()
# df['No of Student'].str.replace(',','').astype(int)
df['University Rank'] = [val for val in list_uni_rank]
df
# Out:
#       University Rank                            Name of University  \
# 0                   1                          University of Oxford
# 1                   2                            Harvard University
# 2                   3                       University of Cambridge
# 3                   3                           Stanford University
# 4                   5         Massachusetts Institute of Technology
# ...               ...                                           ...
# 1692             1501  Wrocław University of Science and Technology
# 1693             1501                          Yamaguchi University
# 1694             1501                            Yanshan University
# 1695             1501                           Yeditepe University
# 1696             1501            Zonguldak Bülent Ecevit University
#
#             Location No of student  No of student per staff  \
# 0     United Kingdom        20,965                     10.6
# ...

# %% [markdown]
# 2. Distribution

# %%
top_100_uni = df[df['University Rank'] <= 100]
top_100_uni = top_100_uni.groupby('Location')
top_100_uni_dis = top_100_uni['Name of University'].count()
top_100_uni_dis
# Out:
# Location
# Australia          4
# Canada             2
# China              3
# France             4
# Germany            5
# Japan              1
# Netherlands        4
# Singapore          1
# South Korea        1
# Sweden             1
# Switzerland        4
# United Kingdom     7
# United States     31
# Name: Name of University, dtype: int64

# %% [markdown]
# Bar Chart Vizualization

# %%
import matplotlib.pyplot as plt
top_100_uni_dis.plot(kind = 'bar')
plt.title('Distribution University')
plt.xlabel('Country Name')
plt.ylabel('Number of university')
plt.show()

# %%
result_chart = top_100_uni.agg({"Name of University" : "count"}).sort_values("Name of University", ascending=True)
result_chart.plot.barh()
# Out:
# <Axes: ylabel='Location'>

# %% [markdown]
# **Average Number of Students in Top 10 Universities:**

# %%
top_10_uni = df[df['University Rank'] <= 10]
# print(int(top_10_uni['No of student'][9]))
top_10_uni['No of student'] = top_10_uni['No of student'].str.replace(',', '').astype(int)
avg_student = top_10_uni['No of student'].mean()
print("The Average Number of Students in Top 10 Universities:",avg_student)
# Out:
# The Average Number of Students in Top 10 Universities: 17408.0
# C:\Users\huyen\AppData\Local\Temp\ipykernel_34752\4239867265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_uni['No of student'] = top_10_uni['No of student'].str.replace(',', '').astype(int)

# %% [markdown]
# **Top 10 Universities with >50% International Students:**

# %%
df['International Student'][0]
# Out:
# '42%'

# %%
df['International Student'] = [int(val) if val else None for val in df['International Student'].str.replace('%','')]
df[df['International Student'] > 50].sort_values(by='University Rank').head(10)
# Out:
#      University Rank                                Name of University  \
# 9                 10                           Imperial College London
# 21                22                                               UCL
# 34                35                             King’s College London
# 36                37  London School of Economics and Political Science
# 40                41          École Polytechnique Fédérale de Lausanne
# 61                62                    Australian National University
# 144              145                             Maastricht University
# 237              201                Università della Svizzera italiana
# 216              201                          University of Luxembourg
# 286              251                             University of Sharjah
#
#                  Location No of student  No of student per staff  \
# 9          United Kingdom        18,545                     11.2
# ...

# %% [markdown]
# **Top 10 Universities with Predominantly Female Presence:**

# %%
type(df['Female:Male Ratio'][0])
df['Female Ratio'] = [int(val[0]) for val in df['Female:Male Ratio'].str.split(' : ')]

# %%
df.sort_values(['Female Ratio', 'University Rank'], ascending=[False, True]).head(10)
# Out:
#       University Rank                               Name of University  \
# 812               801                           Ewha Womans University
# 911               801      Princess Nourah bint Abdulrahman University
# 1180             1201                            Banasthali University
# 1285             1201       Lahore College for Women University (LCWU)
# 1448             1501                               Alzahra University
# 1615             1501                            Ochanomizu University
# 670               601           Imam Abdulrahman Bin Faisal University
# 1199             1201  Chang Gung University of Science and Technology
# 592               501                                 Zayed University
# 384               351                         Royal Veterinary College
#
#                   Location No of student  No of student per staff  \
# 812            South Korea        14,746                     17.5
# ...
